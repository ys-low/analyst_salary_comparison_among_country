# %%
import pandas as pd
import os 

current_dir = os.getcwd() 
relative_path=os.path.abspath(os.path.join(current_dir, os.pardir))

# %%
df = pd.DataFrame(pd.read_csv(
    relative_path+"\\Web_Scraping\\full_data.csv",).iloc[:, 1:])
#

# %%
df
# Out:
#                    country     salary  salary_in_usd avg_salary  cost_living
# 0                Argentina    1503900            NaN      9,960        576.0
# 1                Australia     111100   78952.285957     57,170       1947.0
# 2                  Belarus  952071300            NaN        NaN        581.0
# 3   Bosnia and Herzegovina      50900            NaN        NaN        546.0
# 4                   Brazil     227000   44758.184524      7,740        661.0
# 5                 Bulgaria      57100   31720.600266        NaN        639.0
# 6                   Canada      86300   64759.272049     48,310       1832.0
# 7                    Chile   27384400            NaN        NaN        840.0
# 8                    China     235000   34648.866875     11,880        758.0
# 9                 Colombia   41831600            NaN        NaN        548.0
# 10                 Croatia     261500   37008.677768     17,630        896.0
# ...

# %%
df = df.replace({'avg_salary': ","}, 
    {'avg_salary': ''}, regex=True)

# %%
df.dtypes
# Out:
# country           object
# salary             int64
# salary_in_usd    float64
# avg_salary        object
# cost_living      float64
# dtype: object

# %%
df.at[0,'salary_in_usd']='8042.85'
df.at[2,'salary_in_usd']='37633.4'
df.at[3,'salary_in_usd']='28279.5'
df.at[7,'salary_in_usd']='33937.2'
df.at[9,'salary_in_usd']='9170.49'
df.at[13,'salary_in_usd']='25931.1'
df.at[22,'salary_in_usd']='24315.2'
df.at[24,'salary_in_usd']='10319.4'
df.at[25,'salary_in_usd']='28221.2'
df.at[30,'salary_in_usd']='24927.7'
df.at[37,'salary_in_usd']='31783.1'
df.at[39,'salary_in_usd']='19347.6'
df.at[14,'cost_living']='2822'

# %%
df["salary_in_usd"] = pd.to_numeric(df["salary_in_usd"], errors='coerce')
df["avg_salary"] = pd.to_numeric(df["avg_salary"], errors='coerce')
df["cost_living"] = pd.to_numeric(df["cost_living"], errors='coerce')

# %%
#df.to_csv(relative_path+"\\Clustering\\cleaned_data.csv")
